# %%
import pandas as pd
import scipy.stats as stats
from scipy.stats import ttest_ind
import numpy as np
import pandas as pd
import scipy

# %%
disease_df = pd.read_csv("obs_diabetes.csv") 
pop_df = pd.read_csv("pop_data_by_county.csv")

# %%
disease_df.head()
# Out:
#    FIPS State   County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0  1001    AL  Autauga                   11.4                   13.0
# 1  1003    AL  Baldwin                    9.8                   10.4
# 2  1005    AL  Barbour                   13.6                   18.4
# 3  1007    AL     Bibb                   11.1                   14.8
# 4  1009    AL   Blount                   11.4                   14.1
#
#    PCT_OBESE_ADULTS08  PCT_OBESE_ADULTS13  PCT_HSPA15  RECFAC09  RECFAC14  \
# 0                31.5                34.1        25.4         4         5
# 1                26.2                27.4        25.4        18        25
# 2                37.6                44.4        25.4         1         0
# 3                32.3                40.3        25.4         1         1
# 4                31.9                34.6        25.4         3         3
#
#    PCH_RECFAC_09_14  RECFACPTH09  RECFACPTH14  PCH_RECFACPTH_09_14
# ...

# %%
pop_df.head()
# Out:
#     FIPS      State    County 2010 Census Population  \
# 0  1001.0   Alabama  Autauga                  54,571
# 1  1003.0   Alabama  Baldwin                 182,265
# 2  1005.0   Alabama  Barbour                  27,457
# 3  1007.0   Alabama     Bibb                  22,915
# 4  1009.0   Alabama   Blount                  57,322
#
#   Population Estimate, 2011 Population Estimate, 2012  \
# 0                    55,255                    55,027
# 1                   186,653                   190,403
# 2                    27,326                    27,132
# 3                    22,736                    22,645
# 4                    57,707                    57,772
#
#   Population Estimate, 2013 Population Estimate, 2014  \
# 0                    54,792                    54,977
# 1                   195,147                   199,745
# 2                    26,938                    26,763
# 3                    22,501                    22,511
# ...

# %%
states_df = pd.read_csv("states.csv")
states_df.head()
# Out:
#    state_name abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
disease_df = pd.merge(disease_df, states_df, how = "inner", left_on = "State", right_on = "abbreviation")
disease_df.head()
# Out:
#    FIPS State   County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0  1001    AL  Autauga                   11.4                   13.0
# 1  1003    AL  Baldwin                    9.8                   10.4
# 2  1005    AL  Barbour                   13.6                   18.4
# 3  1007    AL     Bibb                   11.1                   14.8
# 4  1009    AL   Blount                   11.4                   14.1
#
#    PCT_OBESE_ADULTS08  PCT_OBESE_ADULTS13  PCT_HSPA15  RECFAC09  RECFAC14  \
# 0                31.5                34.1        25.4         4         5
# 1                26.2                27.4        25.4        18        25
# 2                37.6                44.4        25.4         1         0
# 3                32.3                40.3        25.4         1         1
# 4                31.9                34.6        25.4         3         3
#
#    PCH_RECFAC_09_14  RECFACPTH09  RECFACPTH14  PCH_RECFACPTH_09_14 state_name  \
# ...

# %%
disease_df = disease_df.drop("abbreviation", axis = 1)
disease_df.head()
# Out:
#    FIPS State   County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0  1001    AL  Autauga                   11.4                   13.0
# 1  1003    AL  Baldwin                    9.8                   10.4
# 2  1005    AL  Barbour                   13.6                   18.4
# 3  1007    AL     Bibb                   11.1                   14.8
# 4  1009    AL   Blount                   11.4                   14.1
#
#    PCT_OBESE_ADULTS08  PCT_OBESE_ADULTS13  PCT_HSPA15  RECFAC09  RECFAC14  \
# 0                31.5                34.1        25.4         4         5
# 1                26.2                27.4        25.4        18        25
# 2                37.6                44.4        25.4         1         0
# 3                32.3                40.3        25.4         1         1
# 4                31.9                34.6        25.4         3         3
#
#    PCH_RECFAC_09_14  RECFACPTH09  RECFACPTH14  PCH_RECFACPTH_09_14 state_name
# ...

# %%
pop_df['State'] = pop_df['State'].str.strip() #strip trailing white space from state name
county_data = pd.merge(disease_df, pop_df, how = "inner", left_on = "state_name", right_on = "State")
county_data
# Out:
#          FIPS State_x  County_x  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0        1001      AL   Autauga                   11.4                   13.0
# 1        1001      AL   Autauga                   11.4                   13.0
# 2        1001      AL   Autauga                   11.4                   13.0
# 3        1001      AL   Autauga                   11.4                   13.0
# 4        1001      AL   Autauga                   11.4                   13.0
# 5        1001      AL   Autauga                   11.4                   13.0
# 6        1001      AL   Autauga                   11.4                   13.0
# 7        1001      AL   Autauga                   11.4                   13.0
# 8        1001      AL   Autauga                   11.4                   13.0
# 9        1001      AL   Autauga                   11.4                   13.0
# 10       1001      AL   Autauga                   11.4                   13.0
# ...

# %%
county_data.shape
# Out:
# (303041, 25)

# %%
disease_df.head()
# Out:
#    FIPS State   County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0  1001    AL  Autauga                   11.4                   13.0
# 1  1003    AL  Baldwin                    9.8                   10.4
# 2  1005    AL  Barbour                   13.6                   18.4
# 3  1007    AL     Bibb                   11.1                   14.8
# 4  1009    AL   Blount                   11.4                   14.1
#
#    PCT_OBESE_ADULTS08  PCT_OBESE_ADULTS13  PCT_HSPA15  RECFAC09  RECFAC14  \
# 0                31.5                34.1        25.4         4         5
# 1                26.2                27.4        25.4        18        25
# 2                37.6                44.4        25.4         1         0
# 3                32.3                40.3        25.4         1         1
# 4                31.9                34.6        25.4         3         3
#
#    PCH_RECFAC_09_14  RECFACPTH09  RECFACPTH14  PCH_RECFACPTH_09_14 state_name
# ...

# %%
pd.merge(disease_df, pop_df, how='inner', left_on='state_name', right_on='State')
# Out:
# Empty DataFrame
# Columns: [FIPS, State_x, County_x, PCT_DIABETES_ADULTS08, PCT_DIABETES_ADULTS13, PCT_OBESE_ADULTS08, PCT_OBESE_ADULTS13, PCT_HSPA15, RECFAC09, RECFAC14, PCH_RECFAC_09_14, RECFACPTH09, RECFACPTH14, PCH_RECFACPTH_09_14, state_name, FIPS , State_y, County_y, 2010 Census Population, Population Estimate, 2011, Population Estimate, 2012, Population Estimate, 2013, Population Estimate, 2014, Population Estimate, 2015, Population Estimate, 2016]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  nan]
