# %%
import pandas as pd
import scipy.stats as stats
from scipy.stats import ttest_ind
import numpy as np
import pandas as pd
import scipy

# %%
snap_df = pd.read_csv("percentage_data.csv")

# %%
snap_df.head()
# Out:
#    Unnamed: 0 State  % of WIC Participants  \
# 0           0    AL               2.878178
# 1           1    AK               3.162859
# 2           2    AZ               2.754891
# 3           3    AR               3.034377
# 4           4    CA               3.735160
#
#    % of School Lunch Program Participants  \
# 0                               11.174373
# 1                                7.201662
# 2                                9.763085
# 3                               11.238083
# 4                                8.594137
#
#    % of School Breakfast Program Participants  % of Summer Food Participants  \
# 0                                    4.641764                       0.627563
# 1                                    2.845407                       0.696638
# 2                                    4.370366                       0.357575
# 3                                    5.623351                       1.417735
# ...

# %%
snap_df = snap_df.drop("Unnamed: 0", axis = 1)
snap_df.head()
# Out:
#   State  % of WIC Participants  % of School Lunch Program Participants  \
# 0    AL               2.878178                               11.174373
# 1    AK               3.162859                                7.201662
# 2    AZ               2.754891                                9.763085
# 3    AR               3.034377                               11.238083
# 4    CA               3.735160                                8.594137
#
#    % of School Breakfast Program Participants  % of Summer Food Participants  \
# 0                                    4.641764                       0.627563
# 1                                    2.845407                       0.696638
# 2                                    4.370366                       0.357575
# 3                                    5.623351                       1.417735
# 4                                    3.958088                       0.299174
#
#    % Adults with Diabetes  % Obese Adults  State Population
# ...

# %%
top_ten_wic = snap_df.sort_values("% of WIC Participants", ascending = False)
top_ten_wic.head(10)

top_ten_wic.to_csv("top_ten_wic.csv", encoding = "utf-8", index = True, header = True)

# %%
top_ten_lunch = snap_df.sort_values("% of School Lunch Program Participants", ascending = False)
top_ten_lunch.head(10)

top_ten_lunch.to_csv("top_ten_lunch.csv", encoding = "utf-8", index = True, header = True)

# %%
top_ten_breakfast = snap_df.sort_values("% of School Breakfast Program Participants", ascending = False)
top_ten_breakfast.head(10)

top_ten_breakfast.to_csv("top_ten_breakfast.csv", encoding = "utf-8", index = True, header = True)

# %%
top_ten_summer = snap_df.sort_values("% of Summer Food Participants", ascending = False)
top_ten_summer.head(10)
# Out:
#    State  % of WIC Participants  % of School Lunch Program Participants  \
# 8     DC               2.414486                                7.789853
# 32    NY               2.609082                                8.761756
# 49    WI               1.980949                                9.789854
# 3     AR               3.034377                               11.238083
# 12    ID               2.685590                                9.937215
# 20    MD               2.438456                                7.127581
# 40    SC               2.606748                               10.026523
# 29    NH               1.185390                                7.363496
# 31    NM               2.942270                               10.559550
# 45    VT               2.365660                                8.217782
#
#     % of School Breakfast Program Participants  % of Summer Food Participants  \
# 8                                     5.371978                       5.357344
# ...

# %%
top_ten_diabetes = snap_df.sort_values("% Adults with Diabetes", ascending = False)
top_ten_diabetes.head(10)
top_ten_diabetes.to_csv("top_ten_diabetes.csv", encoding = "utf-8", index = True, header = True)

# %%
top_ten_obese = snap_df.sort_values("% Obese Adults", ascending = False)
top_ten_obese.head(10)
top_ten_obese.to_csv("top_ten_obese.csv", encoding = "utf-8", index = True, header = True)
